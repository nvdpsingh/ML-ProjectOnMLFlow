# %%
import pandas as pd
import numpy as np
import mlflow
import mlflow.sklearn
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing()

# %%
print(housing)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#           39.37      , -121.24      ]], shape=(20640, 8)), 'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894], shape=(20640,)), 'frame': None, 'target_names': ['MedHouseVal'], 'feature_names': ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude'], 'DESCR': '.. _california_housing_dataset:\n\nCalifornia Housing dataset\n--------------------------\n\n**Data Set Characteristics:**\n\n:Number of Instances: 20640\n\n:Number of Attributes: 8 numeric, predictive attributes and the target\n\n:Attribute Information:\n    - MedInc        median income in block group\n    - HouseAge      median house age in block group\n    - AveRooms      average number of rooms per household\n    - AveBedrms     average number of bedrooms per household\n    - Population    block group population\n    - AveOccup      average number of household members\n    - Latitude      block group latitude\n    - Longitude     block group longitude\n\n:Missing Attribute Values: None\n\nThis dataset was obtained from the StatLib repository.\nhttps://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html\n\nThe target variable is the median house value for California districts,\nexpressed in hundreds of thousands of dollars ($100,000).\n\nThis dataset was derived from the 1990 U.S. census, using one row per census\nblock group. A block group is the smallest geographical unit for which the U.S.\nCensus Bureau publishes sample data (a block group typically has a population\nof 600 to 3,000 people).\n\nA household is a group of people residing within a home. Since the average\nnumber of rooms and bedrooms in this dataset are provided per household, these\ncolumns may take surprisingly large values for block groups with few households\nand many empty houses, such as vacation resorts.\n\nIt can be downloaded/loaded using the\n:func:`sklearn.datasets.fetch_california_housing` function.\n\n.. rubric:: References\n\n- Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,\n  Statistics and Probability Letters, 33 (1997) 291-297\n'}

# %%
##Preparing the dataset
data = pd.DataFrame(housing.data,columns=housing.feature_names)
data["Price"]=housing.target
data.head(10)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5  4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# 6  3.6591      52.0  4.931907   0.951362      1094.0  2.128405     37.84
# 7  3.1200      52.0  4.797527   1.061824      1157.0  1.788253     37.84
# 8  2.0804      42.0  4.294118   1.117647      1206.0  2.026891     37.84
# 9  3.6912      52.0  4.970588   0.990196      1551.0  2.172269     37.84
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422
# 5    -122.25  2.697
# 6    -122.25  2.992
# 7    -122.25  2.414
# 8    -122.26  2.267
# 9    -122.25  2.611

# %%
###Train Test SPlit, Model Hyperparameter Tuning, Mlflow Experiments
from urllib.parse import urlparse
y = data['Price']
X = data.drop(columns =['Price'])

# %%
y
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: Price, Length: 20640, dtype: float64

# %%
## Hyperparameter tuning using Grid Search CV

def hyperparameter_tuning(X_train,y_train,param_grid):
    rf = RandomForestRegressor()
    grid_search = GridSearchCV(estimator=rf,param_grid=param_grid,cv=3,n_jobs=-1,verbose = 2, scoring = "neg_mean_squared_error")
    grid_search.fit(X_train,y_train)
    return grid_search

# %%
## Split data into training and test sets
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20)

from mlflow.models import infer_signature
signature=infer_signature(X_train,y_train)

## Define the hyperparameter grid
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [5, 10, None],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

## start the MLFLOW Experiments

with mlflow.start_run():
    ## Perform hyperparameter tuning
    grid_search=hyperparameter_tuning(X_train,y_train,param_grid)

    ## Get the best model
    best_model=grid_search.best_estimator_

    ## Evaluate the best model
    y_pred=best_model.predict(X_test)
    mse=mean_squared_error(y_test,y_pred)

    ## Log best parameters and metrics
    mlflow.log_param("best_n_estimators",grid_search.best_params_['n_estimators'])
    mlflow.log_param("best_max_depth", grid_search.best_params_['max_depth'])
    mlflow.log_param("best_min_samples_split", grid_search.best_params_['min_samples_split'])
    mlflow.log_param("best_min_samples_leaf", grid_search.best_params_['min_samples_leaf'])
    mlflow.log_metric("mse",mse)

    ## Tracking url

    mlflow.set_tracking_uri(uri="http://127.0.0.1:5000")
    tracking_url_type_store=urlparse(mlflow.get_tracking_uri()).scheme

    if tracking_url_type_store !='file':
        mlflow.sklearn.log_model(best_model,"model",registered_model_name="Best Randomforest Model")
    else:
        mlflow.sklearn.log_model(best_model,"model",signature=signature)

    print(f"Best Hyperparameters: {grid_search.best_params_}")
    print(f"Mean Squared Error: {mse}")
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# 2025/08/25 14:20:18 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# ---------------------------------------------------------------------------
# RestException                             Traceback (most recent call last)
# Cell In[7], line 41
#      40 if tracking_url_type_store !='file':
# ---> 41     mlflow.sklearn.log_model(best_model,"model",registered_model_name="Best Randomforest Model")
#      42 else:
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/sklearn/__init__.py:426, in log_model(sk_model, artifact_path, conda_env, code_paths, serialization_format, registered_model_name, signature, input_example, await_registration_for, pip_requirements, extra_pip_requirements, pyfunc_predict_fn, metadata, params, tags, model_type, step, model_id, name)
#     357 """
#     358 Log a scikit-learn model as an MLflow artifact for the current run. Produces an MLflow Model
#     359 containing the following flavors:
#    (...)
#     424
#     425 """
# --> 426 return Model.log(
#     427     artifact_path=artifact_path,
#     428     name=name,
#     429     flavor=mlflow.sklearn,
#     430     sk_model=sk_model,
#     431     conda_env=conda_env,
#     432     code_paths=code_paths,
#     433     serialization_format=serialization_format,
#     434     registered_model_name=registered_model_name,
#     435     signature=signature,
#     436     input_example=input_example,
#     437     await_registration_for=await_registration_for,
#     438     pip_requirements=pip_requirements,
#     439     extra_pip_requirements=extra_pip_requirements,
#     440     pyfunc_predict_fn=pyfunc_predict_fn,
#     441     metadata=metadata,
#     442     params=params,
#     443     tags=tags,
#     444     model_type=model_type,
#     445     step=step,
#     446     model_id=model_id,
#     447 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/models/model.py:1164, in Model.log(cls, artifact_path, flavor, registered_model_name, await_registration_for, metadata, run_id, resources, auth_policy, prompts, name, model_type, params, tags, step, model_id, **kwargs)
#    1161 else:
#    1162     params = {
#    1163         **(params or {}),
# -> 1164         **(client.get_run(run_id).data.params if run_id else {}),
#    1165     }
#    1166     model = _create_logged_model(
#    1167         # TODO: Update model name
#    1168         name=name,
#    (...)
#    1175         flavor=flavor.__name__ if hasattr(flavor, "__name__") else "custom",
#    1176     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/tracking/client.py:275, in MlflowClient.get_run(self, run_id)
#     232 """
#     233 Fetch the run from backend store. The resulting :py:class:`Run <mlflow.entities.Run>`
#     234 contains a collection of run metadata -- :py:class:`RunInfo <mlflow.entities.RunInfo>`,
#    (...)
#     273
#     274 """
# --> 275 return self._tracking_client.get_run(run_id)
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/tracking/_tracking_service/client.py:100, in TrackingServiceClient.get_run(self, run_id)
#      99 _validate_run_id(run_id)
# --> 100 return self.store.get_run(run_id)
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/store/tracking/rest_store.py:228, in RestStore.get_run(self, run_id)
#     227 req_body = message_to_json(GetRun(run_uuid=run_id, run_id=run_id))
# --> 228 response_proto = self._call_endpoint(GetRun, req_body)
#     229 return Run.from_proto(response_proto.run)
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/store/tracking/rest_store.py:134, in RestStore._call_endpoint(self, api, json_body, endpoint, retry_timeout_seconds)
#     133 response_proto = api.Response()
# --> 134 return call_endpoint(
#     135     self.get_host_creds(),
#     136     endpoint,
#     137     method,
#     138     json_body,
#     139     response_proto,
#     140     retry_timeout_seconds=retry_timeout_seconds,
#     141 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/utils/rest_utils.py:554, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers, retry_timeout_seconds)
#     552     response = http_request(**call_kwargs)
# --> 554 response = verify_rest_response(response, endpoint)
#     555 response_to_parse = response.text
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/utils/rest_utils.py:308, in verify_rest_response(response, endpoint)
#     307 if _can_parse_as_json_object(response.text):
# --> 308     raise RestException(json.loads(response.text))
#     309 else:
#
# RestException: RESOURCE_DOES_NOT_EXIST: Run '786593e5ed0b4b13b6527772226f7179' not found
#
# During handling of the above exception, another exception occurred:
#
# RestException                             Traceback (most recent call last)
# Cell In[7], line 17
#       8 param_grid = {
#       9     'n_estimators': [100, 200],
#      10     'max_depth': [5, 10, None],
#      11     'min_samples_split': [2, 5],
#      12     'min_samples_leaf': [1, 2]
#      13 }
#      15 ## start the MLFLOW Experiments
# ---> 17 with mlflow.start_run():
#      18     ## Perform hyperparameter tuning
#      19     grid_search=hyperparameter_tuning(X_train,y_train,param_grid)
#      21     ## Get the best model
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/tracking/fluent.py:256, in ActiveRun.__exit__(self, exc_type, exc_val, exc_tb)
#     254 if any(r.info.run_id == self.info.run_id for r in active_run_stack):
#     255     status = RunStatus.FINISHED if exc_type is None else RunStatus.FAILED
# --> 256     end_run(RunStatus.to_string(status))
#     258 return exc_type is None
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/tracking/fluent.py:547, in end_run(status)
#     545 last_active_run_id = run.info.run_id
#     546 _last_active_run_id.set(last_active_run_id)
# --> 547 MlflowClient().set_terminated(last_active_run_id, status)
#     548 if last_active_run_id in run_id_to_system_metrics_monitor:
#     549     system_metrics_monitor = run_id_to_system_metrics_monitor.pop(last_active_run_id)
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/tracking/client.py:3438, in MlflowClient.set_terminated(self, run_id, status, end_time)
#    3393 def set_terminated(
#    3394     self, run_id: str, status: str | None = None, end_time: int | None = None
#    3395 ) -> None:
#    3396     """Set a run's status to terminated.
#    3397
#    3398     Args:
#    (...)
#    3436
#    3437     """
# -> 3438     self._tracking_client.set_terminated(run_id, status, end_time)
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/tracking/_tracking_service/client.py:773, in TrackingServiceClient.set_terminated(self, run_id, status, end_time)
#     769 # Tell the store to stop async logging: stop accepting new data and log already enqueued
#     770 # data in the background. This call is making sure every async logging data has been
#     771 # submitted for logging, but not necessarily finished logging.
#     772 self.store.shut_down_async_logging()
# --> 773 self._log_url(run_id)
#     774 self.store.update_run_info(
#     775     run_id,
#     776     run_status=RunStatus.from_string(status),
#     777     end_time=end_time,
#     778     run_name=None,
#     779 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/tracking/_tracking_service/client.py:739, in TrackingServiceClient._log_url(self, run_id)
#     737 if host_url is None:
#     738     host_url = self.store.get_host_creds().host.rstrip("/")
# --> 739 run = self.store.get_run(run_id)
#     741 # Check for a special run tag that indicates the run is triggered by evaluation.
#     742 # MLflow already shows a link to evaluation results so no need to print it again.
#     743 if (
#     744     is_eval_tag := run.data.tags.get(MLFLOW_RUN_IS_EVALUATION)
#     745 ) and is_eval_tag.lower() == "true":
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/store/tracking/rest_store.py:228, in RestStore.get_run(self, run_id)
#     218 """
#     219 Fetch the run from backend store
#     220
#    (...)
#     225     A single Run object if it exists, otherwise raises an Exception
#     226 """
#     227 req_body = message_to_json(GetRun(run_uuid=run_id, run_id=run_id))
# --> 228 response_proto = self._call_endpoint(GetRun, req_body)
#     229 return Run.from_proto(response_proto.run)
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/store/tracking/rest_store.py:134, in RestStore._call_endpoint(self, api, json_body, endpoint, retry_timeout_seconds)
#     132     endpoint, method = _METHOD_TO_INFO[api]
#     133 response_proto = api.Response()
# --> 134 return call_endpoint(
#     135     self.get_host_creds(),
#     136     endpoint,
#     137     method,
#     138     json_body,
#     139     response_proto,
#     140     retry_timeout_seconds=retry_timeout_seconds,
#     141 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/utils/rest_utils.py:554, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers, retry_timeout_seconds)
#     551     call_kwargs["json"] = json_body
#     552     response = http_request(**call_kwargs)
# --> 554 response = verify_rest_response(response, endpoint)
#     555 response_to_parse = response.text
#     556 try:
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/utils/rest_utils.py:308, in verify_rest_response(response, endpoint)
#     306 if response.status_code != 200:
#     307     if _can_parse_as_json_object(response.text):
# --> 308         raise RestException(json.loads(response.text))
#     309     else:
#     310         base_msg = (
#     311             f"API request to endpoint {endpoint} "
#     312             f"failed with error code {response.status_code} != 200"
#     313         )
#
# RestException: RESOURCE_DOES_NOT_EXIST: Run '786593e5ed0b4b13b6527772226f7179' not found
